# %% [markdown]
# ## Global Population Estimates
# The World Bank's global population estimates --the dataset can be found from this url:-
# "https://www.kaggle.com/datasets/theworldbank/global-population-estimates"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importing pandas and numpy libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/data.csv')

# %%
#showing first 5 rows
df.head()
# Out:
#   Country Name Country Code  ... 2049 [YR2049]  2050 [YR2050]
# 0  Afghanistan          AFG  ...     44.471497      43.992485
# 1  Afghanistan          AFG  ...      7.935899       8.175734
# 2  Afghanistan          AFG  ...     36.535598      35.816751
# 3  Afghanistan          AFG  ...           NaN  430000.000000
# 4  Afghanistan          AFG  ...           NaN  452000.000000
#
# [5 rows x 95 columns]

# %%
print("Shape of df =",df.shape)
# Out:
# Shape of df = (44812, 95)

# %% [markdown]
# Rows: 44812 and
# columns: 95

# %%
# Print all columns with data type object
print(df.columns.values[df.dtypes=='object'])
# Out:
# ['Country Name' 'Country Code' 'Series Name' 'Series Code']

# %%
# Print all columns with data type float64
print(df.columns.values[df.dtypes=='float64'])
# Out:
# ['1960 [YR1960]' '1961 [YR1961]' '1962 [YR1962]' '1963 [YR1963]'
#  '1964 [YR1964]' '1965 [YR1965]' '1966 [YR1966]' '1967 [YR1967]'
#  '1968 [YR1968]' '1969 [YR1969]' '1970 [YR1970]' '1971 [YR1971]'
#  '1972 [YR1972]' '1973 [YR1973]' '1974 [YR1974]' '1975 [YR1975]'
#  '1976 [YR1976]' '1977 [YR1977]' '1978 [YR1978]' '1979 [YR1979]'
#  '1980 [YR1980]' '1981 [YR1981]' '1982 [YR1982]' '1983 [YR1983]'
#  '1984 [YR1984]' '1985 [YR1985]' '1986 [YR1986]' '1987 [YR1987]'
#  '1988 [YR1988]' '1989 [YR1989]' '1990 [YR1990]' '1991 [YR1991]'
#  '1992 [YR1992]' '1993 [YR1993]' '1994 [YR1994]' '1995 [YR1995]'
#  '1996 [YR1996]' '1997 [YR1997]' '1998 [YR1998]' '1999 [YR1999]'
#  '2000 [YR2000]' '2001 [YR2001]' '2002 [YR2002]' '2003 [YR2003]'
#  '2004 [YR2004]' '2005 [YR2005]' '2006 [YR2006]' '2007 [YR2007]'
#  '2008 [YR2008]' '2009 [YR2009]' '2010 [YR2010]' '2011 [YR2011]'
#  '2012 [YR2012]' '2013 [YR2013]' '2014 [YR2014]' '2015 [YR2015]'
#  '2016 [YR2016]' '2017 [YR2017]' '2018 [YR2018]' '2019 [YR2019]'
#  '2020 [YR2020]' '2021 [YR2021]' '2022 [YR2022]' '2023 [YR2023]'
#  '2024 [YR2024]' '2025 [YR2025]' '2026 [YR2026]' '2027 [YR2027]'
#  '2028 [YR2028]' '2029 [YR2029]' '2030 [YR2030]' '2031 [YR2031]'
#  '2032 [YR2032]' '2033 [YR2033]' '2034 [YR2034]' '2035 [YR2035]'
#  '2036 [YR2036]' '2037 [YR2037]' '2038 [YR2038]' '2039 [YR2039]'
#  '2040 [YR2040]' '2041 [YR2041]' '2042 [YR2042]' '2043 [YR2043]'
#  '2044 [YR2044]' '2045 [YR2045]' '2046 [YR2046]' '2047 [YR2047]'
#  '2048 [YR2048]' '2049 [YR2049]' '2050 [YR2050]']

# %% [markdown]
# # Dropping last 5 rows as they contain catagorical null values

# %%
# Removing last n rows
df = df.iloc[:-5]

# %% [markdown]
# # Seperating Numeric data from Categorical data

# %%
# numeric data
data_numeric = df.select_dtypes(include=[np.number])
numeric_cols = data_numeric.columns.values
print(f'There are {len(numeric_cols)} numeric columns in the dataset','\n')
# Out:
# There are 91 numeric columns in the dataset

# %%
# categorical data
data_categorical = df.select_dtypes(exclude=[np.number])
non_numeric_cols = data_categorical.columns.values
print(f'There are {len(non_numeric_cols)} non-numeric columns in the dataset','\n')
# Out:
# There are 4 non-numeric columns in the dataset

# %%
df.describe()
# Out:
#        1960 [YR1960]  1961 [YR1961]  ...  2049 [YR2049]  2050 [YR2050]
# count   3.585000e+04   3.598600e+04  ...   2.305900e+04   3.450500e+04
# mean    4.353267e+06   4.394991e+06  ...   2.224035e+07   1.505221e+07
# std     4.922851e+07   4.966977e+07  ...   1.981883e+08   1.632086e+08
# min    -2.374024e+00  -2.498824e+00  ...  -1.771285e+00  -1.807278e+00
# 25%     1.178539e+01   1.146330e+01  ...   6.648373e+00   1.069486e+01
# 50%     4.704500e+03   4.657500e+03  ...   6.723943e+01   2.100000e+04
# 75%     9.747975e+04   9.893250e+04  ...   7.690000e+05   4.100000e+05
# max     3.034193e+09   3.075115e+09  ...   9.671774e+09   9.722319e+09
#
# [8 rows x 91 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44807 entries, 0 to 44806
# Data columns (total 95 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   44807 non-null  object
#  1   Country Code   44807 non-null  object
#  2   Series Name    44807 non-null  object
#  3   Series Code    44807 non-null  object
#  4   1960 [YR1960]  35850 non-null  float64
#  5   1961 [YR1961]  35986 non-null  float64
#  6   1962 [YR1962]  36459 non-null  float64
#  7   1963 [YR1963]  36025 non-null  float64
#  8   1964 [YR1964]  36056 non-null  float64
#  9   1965 [YR1965]  36073 non-null  float64
#  10  1966 [YR1966]  36085 non-null  float64
#  11  1967 [YR1967]  36565 non-null  float64
#  12  1968 [YR1968]  36123 non-null  float64
#  13  1969 [YR1969]  36165 non-null  float64
#  14  1970 [YR1970]  36200 non-null  float64
#  15  1971 [YR1971]  36211 non-null  float64
#  16  1972 [YR1972]  36691 non-null  float64
#  17  1973 [YR1973]  36227 non-null  float64
#  18  1974 [YR1974]  36236 non-null  float64
#  19  1975 [YR1975]  36257 non-null  float64
#  20  1976 [YR1976]  36272 non-null  float64
#  21  1977 [YR1977]  36742 non-null  float64
#  22  1978 [YR1978]  36298 non-null  float64
#  23  1979 [YR1979]  36313 non-null  float64
#  24  1980 [YR1980]  36330 non-null  float64
#  25  1981 [YR1981]  36352 non-null  float64
#  26  1982 [YR1982]  36843 non-null  float64
#  27  1983 [YR1983]  36381 non-null  float64
#  28  1984 [YR1984]  36407 non-null  float64
#  29  1985 [YR1985]  36410 non-null  float64
#  30  1986 [YR1986]  36424 non-null  float64
#  31  1987 [YR1987]  36910 non-null  float64
#  32  1988 [YR1988]  36426 non-null  float64
#  33  1989 [YR1989]  36432 non-null  float64
#  34  1990 [YR1990]  38376 non-null  float64
#  35  1991 [YR1991]  37208 non-null  float64
#  36  1992 [YR1992]  37633 non-null  float64
#  37  1993 [YR1993]  37143 non-null  float64
#  38  1994 [YR1994]  37154 non-null  float64
#  39  1995 [YR1995]  37207 non-null  float64
#  40  1996 [YR1996]  37213 non-null  float64
#  41  1997 [YR1997]  37692 non-null  float64
#  42  1998 [YR1998]  37210 non-null  float64
#  43  1999 [YR1999]  37216 non-null  float64
#  44  2000 [YR2000]  38169 non-null  float64
#  45  2001 [YR2001]  37224 non-null  float64
#  46  2002 [YR2002]  37710 non-null  float64
#  47  2003 [YR2003]  37223 non-null  float64
#  48  2004 [YR2004]  37227 non-null  float64
#  49  2005 [YR2005]  37235 non-null  float64
#  50  2006 [YR2006]  37240 non-null  float64
#  51  2007 [YR2007]  37714 non-null  float64
#  52  2008 [YR2008]  37473 non-null  float64
#  53  2009 [YR2009]  37475 non-null  float64
#  54  2010 [YR2010]  38407 non-null  float64
#  55  2011 [YR2011]  37469 non-null  float64
#  56  2012 [YR2012]  37545 non-null  float64
#  57  2013 [YR2013]  37295 non-null  float64
#  58  2014 [YR2014]  37278 non-null  float64
#  59  2015 [YR2015]  38150 non-null  float64
#  60  2016 [YR2016]  33739 non-null  float64
#  61  2017 [YR2017]  23932 non-null  float64
#  62  2018 [YR2018]  23059 non-null  float64
#  63  2019 [YR2019]  23059 non-null  float64
#  64  2020 [YR2020]  34505 non-null  float64
#  65  2021 [YR2021]  23059 non-null  float64
#  66  2022 [YR2022]  23932 non-null  float64
#  67  2023 [YR2023]  23059 non-null  float64
#  68  2024 [YR2024]  23059 non-null  float64
#  69  2025 [YR2025]  34505 non-null  float64
#  70  2026 [YR2026]  23059 non-null  float64
#  71  2027 [YR2027]  23932 non-null  float64
#  72  2028 [YR2028]  23059 non-null  float64
#  73  2029 [YR2029]  23059 non-null  float64
#  74  2030 [YR2030]  34505 non-null  float64
#  75  2031 [YR2031]  23059 non-null  float64
#  76  2032 [YR2032]  23932 non-null  float64
#  77  2033 [YR2033]  23059 non-null  float64
#  78  2034 [YR2034]  23059 non-null  float64
#  79  2035 [YR2035]  34505 non-null  float64
#  80  2036 [YR2036]  23059 non-null  float64
#  81  2037 [YR2037]  23932 non-null  float64
#  82  2038 [YR2038]  23059 non-null  float64
#  83  2039 [YR2039]  23059 non-null  float64
#  84  2040 [YR2040]  34505 non-null  float64
#  85  2041 [YR2041]  23059 non-null  float64
#  86  2042 [YR2042]  23932 non-null  float64
#  87  2043 [YR2043]  23059 non-null  float64
#  88  2044 [YR2044]  23059 non-null  float64
#  89  2045 [YR2045]  34505 non-null  float64
#  90  2046 [YR2046]  23059 non-null  float64
#  91  2047 [YR2047]  23932 non-null  float64
#  92  2048 [YR2048]  23059 non-null  float64
#  93  2049 [YR2049]  23059 non-null  float64
#  94  2050 [YR2050]  34505 non-null  float64
# dtypes: float64(91), object(4)
# memory usage: 32.5+ MB

# %% [markdown]
# # Checking null values in Dataset

# %%
df.isnull().sum()
# Out:
# Country Name         0
# Country Code         0
# Series Name          0
# Series Code          0
# 1960 [YR1960]     8957
#                  ...
# 2046 [YR2046]    21748
# 2047 [YR2047]    20875
# 2048 [YR2048]    21748
# 2049 [YR2049]    21748
# 2050 [YR2050]    10302
# Length: 95, dtype: int64

# %% [markdown]
# # Finding percentage of missing data.

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100,5))) # here 5 is used to round percentage upto 5 digits.
# Out:
# Country Name - 0.0%
# Country Code - 0.0%
# Series Name - 0.0%
# Series Code - 0.0%
# 1960 [YR1960] - 19.99018%
# 1961 [YR1961] - 19.68666%
# 1962 [YR1962] - 18.63102%
# 1963 [YR1963] - 19.59962%
# 1964 [YR1964] - 19.53043%
# 1965 [YR1965] - 19.49249%
# 1966 [YR1966] - 19.46571%
# 1967 [YR1967] - 18.39445%
# 1968 [YR1968] - 19.3809%
# 1969 [YR1969] - 19.28716%
# 1970 [YR1970] - 19.20905%
# 1971 [YR1971] - 19.1845%
# 1972 [YR1972] - 18.11324%
# 1973 [YR1973] - 19.14879%
# 1974 [YR1974] - 19.12871%
# 1975 [YR1975] - 19.08184%
# 1976 [YR1976] - 19.04836%
# 1977 [YR1977] - 17.99942%
# 1978 [YR1978] - 18.99034%
# 1979 [YR1979] - 18.95686%
# 1980 [YR1980] - 18.91892%
# 1981 [YR1981] - 18.86982%
# 1982 [YR1982] - 17.77401%
# 1983 [YR1983] - 18.8051%
# 1984 [YR1984] - 18.74707%
# 1985 [YR1985] - 18.74038%
# 1986 [YR1986] - 18.70913%
# 1987 [YR1987] - 17.62448%
# 1988 [YR1988] - 18.70467%
# 1989 [YR1989] - 18.69128%
# 1990 [YR1990] - 14.35267%
# 1991 [YR1991] - 16.9594%
# 1992 [YR1992] - 16.01089%
# 1993 [YR1993] - 17.10447%
# 1994 [YR1994] - 17.07992%
# 1995 [YR1995] - 16.96164%
# 1996 [YR1996] - 16.94824%
# 1997 [YR1997] - 15.87922%
# 1998 [YR1998] - 16.95494%
# 1999 [YR1999] - 16.94155%
# 2000 [YR2000] - 14.81465%
# 2001 [YR2001] - 16.92369%
# 2002 [YR2002] - 15.83904%
# 2003 [YR2003] - 16.92593%
# 2004 [YR2004] - 16.917%
# 2005 [YR2005] - 16.89915%
# 2006 [YR2006] - 16.88799%
# 2007 [YR2007] - 15.83012%
# 2008 [YR2008] - 16.36798%
# 2009 [YR2009] - 16.36351%
# 2010 [YR2010] - 14.28348%
# 2011 [YR2011] - 16.37691%
# 2012 [YR2012] - 16.20729%
# 2013 [YR2013] - 16.76524%
# 2014 [YR2014] - 16.80318%
# 2015 [YR2015] - 14.85705%
# 2016 [YR2016] - 24.7015%
# 2017 [YR2017] - 46.5887%
# 2018 [YR2018] - 48.53706%
# 2019 [YR2019] - 48.53706%
# 2020 [YR2020] - 22.99194%
# 2021 [YR2021] - 48.53706%
# 2022 [YR2022] - 46.5887%
# 2023 [YR2023] - 48.53706%
# 2024 [YR2024] - 48.53706%
# 2025 [YR2025] - 22.99194%
# 2026 [YR2026] - 48.53706%
# 2027 [YR2027] - 46.5887%
# 2028 [YR2028] - 48.53706%
# 2029 [YR2029] - 48.53706%
# 2030 [YR2030] - 22.99194%
# 2031 [YR2031] - 48.53706%
# 2032 [YR2032] - 46.5887%
# 2033 [YR2033] - 48.53706%
# 2034 [YR2034] - 48.53706%
# 2035 [YR2035] - 22.99194%
# 2036 [YR2036] - 48.53706%
# 2037 [YR2037] - 46.5887%
# 2038 [YR2038] - 48.53706%
# 2039 [YR2039] - 48.53706%
# 2040 [YR2040] - 22.99194%
# 2041 [YR2041] - 48.53706%
# 2042 [YR2042] - 46.5887%
# 2043 [YR2043] - 48.53706%
# 2044 [YR2044] - 48.53706%
# 2045 [YR2045] - 22.99194%
# 2046 [YR2046] - 48.53706%
# 2047 [YR2047] - 46.5887%
# 2048 [YR2048] - 48.53706%
# 2049 [YR2049] - 48.53706%
# 2050 [YR2050] - 22.99194%

# %% [markdown]
# # Visualizing missing data using heatmap

# %%
# visualizing numeric columns
import seaborn as sns
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (15,8)

cols = df[numeric_cols].columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %% [markdown]
# # Changing Null value

# %% [markdown]
# -With median

# %%
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# -with mean

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Datasets/data.csv')

# %%
for col in numeric_cols:
    df2[col] = df2[col].fillna(df[col].mean())

# %% [markdown]
# -with zero

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Datasets/data.csv')

# %%
for col in numeric_cols:
    df3[col] = df3[col].fillna(df[col].median())

# %% [markdown]
# # Dropping some rows with null values from data set

# %%
df.shape
# Out:
# (44807, 95)

# %%
df.tail()
# Out:
#       Country Name Country Code  ... 2049 [YR2049] 2050 [YR2050]
# 44802     Zimbabwe          ZWE  ...  6.723943e+01  2.100000e+04
# 44803     Zimbabwe          ZWE  ...  6.723943e+01  2.100000e+04
# 44804     Zimbabwe          ZWE  ...  1.263300e+07  1.296800e+07
# 44805     Zimbabwe          ZWE  ...  4.315700e+01  4.372400e+01
# 44806     Zimbabwe          ZWE  ...  6.723943e+01  2.100000e+04
#
# [5 rows x 95 columns]

# %%
df.isnull().sum()
# Out:
# Country Name     0
# Country Code     0
# Series Name      0
# Series Code      0
# 1960 [YR1960]    0
#                 ..
# 2046 [YR2046]    0
# 2047 [YR2047]    0
# 2048 [YR2048]    0
# 2049 [YR2049]    0
# 2050 [YR2050]    0
# Length: 95, dtype: int64

# %% [markdown]
# # Ploting heat map after cleaning data

# %%
import seaborn as sns
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (15,8)

cols = df.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %% [markdown]
# # Data Visualization

# %%
print(df['Series Name'].unique())
# Out:
# ['Age dependency ratio (% of working-age population)'
#  'Age dependency ratio, old' 'Age dependency ratio, young'
#  'Age population, age 0, female, interpolated'
#  'Age population, age 0, male, interpolated'
#  'Age population, age 01, female, interpolated'
#  'Age population, age 01, male, interpolated'
#  'Age population, age 02, female, interpolated'
#  'Age population, age 02, male, interpolated'
#  'Age population, age 03, female, interpolated'
#  'Age population, age 03, male, interpolated'
#  'Age population, age 04, female, interpolated'
#  'Age population, age 04, male, interpolated'
#  'Age population, age 05, female, interpolated'
#  'Age population, age 05, male, interpolated'
#  'Age population, age 06, female, interpolated'
#  'Age population, age 06, male, interpolated'
#  'Age population, age 07, female, interpolated'
#  'Age population, age 07, male, interpolated'
#  'Age population, age 08, female, interpolated'
#  'Age population, age 08, male, interpolated'
#  'Age population, age 09, female, interpolated'
#  'Age population, age 09, male, interpolated'
#  'Age population, age 10, female, interpolated'
#  'Age population, age 10, male, interpolated'
#  'Age population, age 11, female, interpolated'
#  'Age population, age 11, male, interpolated'
#  'Age population, age 12, female, interpolated'
#  'Age population, age 12, male, interpolated'
#  'Age population, age 13, female, interpolated'
#  'Age population, age 13, male, interpolated'
#  'Age population, age 14, female, interpolated'
#  'Age population, age 14, male, interpolated'
#  'Age population, age 15, female, interpolated'
#  'Age population, age 15, male, interpolated'
#  'Age population, age 16, female, interpolated'
#  'Age population, age 16, male, interpolated'
#  'Age population, age 17, female, interpolated'
#  'Age population, age 17, male, interpolated'
#  'Age population, age 18, female, interpolated'
#  'Age population, age 18, male, interpolated'
#  'Age population, age 19, female, interpolated'
#  'Age population, age 19, male, interpolated'
#  'Age population, age 20, female, interpolated'
#  'Age population, age 20, male, interpolated'
#  'Age population, age 21, female, interpolated'
#  'Age population, age 21, male, interpolated'
#  'Age population, age 22, female, interpolated'
#  'Age population, age 22, male, interpolated'
#  'Age population, age 23, female, interpolated'
#  'Age population, age 23, male, interpolated'
#  'Age population, age 24, female, interpolated'
#  'Age population, age 24, male, interpolated'
#  'Age population, age 25, female, interpolated'
#  'Age population, age 25, male, interpolated'
#  'Birth rate, crude (per 1,000 people)'
#  'Death rate, crude (per 1,000 people)' 'Female population 00-04'
#  'Female population 05-09' 'Female population 10-14'
#  'Female population 15-19' 'Female population 20-24'
#  'Female population 25-29' 'Female population 30-34'
#  'Female population 35-39' 'Female population 40-44'
#  'Female population 45-49' 'Female population 50-54'
#  'Female population 55-59' 'Female population 60-64'
#  'Female population 65-69' 'Female population 70-74'
#  'Female population 75-79' 'Female population 80+'
#  'Fertility rate, total (births per woman)'
#  'Life expectancy at birth, female (years)'
#  'Life expectancy at birth, male (years)'
#  'Life expectancy at birth, total (years)' 'Male population 00-04'
#  'Male population 05-09' 'Male population 10-14' 'Male population 15-19'
#  'Male population 20-24' 'Male population 25-29' 'Male population 30-34'
#  'Male population 35-39' 'Male population 40-44' 'Male population 45-49'
#  'Male population 50-54' 'Male population 55-59' 'Male population 60-64'
#  'Male population 65-69' 'Male population 70-74' 'Male population 75-79'
#  'Male population 80+'
#  'Mortality rate, adult, female (per 1,000 female adults)'
#  'Mortality rate, adult, male (per 1,000 male adults)'
#  'Mortality rate, infant (per 1,000 live births)'
#  'Mortality rate, infant, female (per 1,000 live births)'
#  'Mortality rate, infant, male (per 1,000 live births)'
#  'Mortality rate, neonatal (per 1,000 live births)'
#  'Mortality rate, under-5 (per 1,000)'
#  'Mortality rate, under-5, female (per 1,000)'
#  'Mortality rate, under-5, male (per 1,000)' 'Net migration'
#  'Number of infant deaths' 'Number of neonatal deaths'
#  'Number of under-five deaths'
#  'Population ages 00-04, female (% of female population)'
#  'Population ages 00-04, male (% of male population)'
#  'Population ages 00-14 (% of total)'
#  'Population ages 00-14, female (% of total)'
#  'Population ages 00-14, male (% of total)' 'Population ages 00-14, total'
#  'Population ages 0-14, female' 'Population ages 0-14, male'
#  'Population ages 05-09, female (% of female population)'
#  'Population ages 05-09, male (% of male population)'
#  'Population ages 10-14, female (% of female population)'
#  'Population ages 15-19, female (% of female population)'
#  'Population ages 15-19, male (% of male population)'
#  'Population ages 15-64 (% of total)' 'Population ages 15-64, female'
#  'Population ages 15-64, female (% of total)'
#  'Population ages 15-64, male' 'Population ages 15-64, male (% of total)'
#  'Population ages 15-64, total'
#  'Population ages 20-24, female (% of female population)'
#  'Population ages 20-24, male (% of male population)'
#  'Population ages 25-29, female (% of female population)'
#  'Population ages 25-29, male (% of male population)'
#  'Population ages 30-34, female (% of female population)'
#  'Population ages 30-34, male (% of male population)'
#  'Population ages 35-39, female (% of female population)'
#  'Population ages 35-39, male (% of male population)'
#  'Population ages 40-44, female (% of female population)'
#  'Population ages 40-44, male (% of male population)'
#  'Population ages 45-49, female (% of female population)'
#  'Population ages 45-49, male (% of male population)'
#  'Population ages 50-54, female (% of female population)'
#  'Population ages 50-54, male (% of male population)'
#  'Population ages 55-59, female (% of female population)'
#  'Population ages 55-59, male (% of male population)'
#  'Population ages 60-64, female (% of female population)'
#  'Population ages 60-64, male (% of male population)'
#  'Population ages 65 and above (% of total)'
#  'Population ages 65 and above, female'
#  'Population ages 65 and above, female (% of total)'
#  'Population ages 65 and above, male'
#  'Population ages 65 and above, male (% of total)'
#  'Population ages 65 and above, total'
#  'Population ages 65-69, female (% of female population)'
#  'Population ages 65-69, male (% of male population)'
#  'Population ages 70-74, female (% of female population)'
#  'Population ages 70-74, male (% of male population)'
#  'Population ages 75-79, female (% of female population)'
#  'Population ages 75-79, male (% of male population)'
#  'Population ages 80 and older, female (% of female population)'
#  'Population ages 80 and older, male (% of male population)'
#  'Population ages10-14, male (% of male population)'
#  'Population growth (annual %)' 'Population, female'
#  'Population, female (% of total)' 'Population, male'
#  'Population, male (% of total)' 'Population, total' 'Rural population'
#  'Rural population (% of total population)'
#  'Rural population growth (annual %)'
#  'Sex ratio at birth (male births per female births)' 'Urban population'
#  'Urban population (% of total)' 'Urban population growth (annual %)']

# %%
World = df.loc[df['Country Name'] == 'World']
World
# Out:
#       Country Name Country Code  ... 2049 [YR2049] 2050 [YR2050]
# 44115        World          WLD  ...  5.994531e+01  6.030438e+01
# 44116        World          WLD  ...  2.499680e+01  2.540814e+01
# 44117        World          WLD  ...  3.426168e+01  3.420047e+01
# 44118        World          WLD  ...  6.723943e+01  2.100000e+04
# 44119        World          WLD  ...  6.723943e+01  2.100000e+04
# ...            ...          ...  ...           ...           ...
# 44283        World          WLD  ... -3.806381e-01 -4.091752e-01
# 44284        World          WLD  ...  6.723943e+01  2.100000e+04
# 44285        World          WLD  ...  6.344244e+09  6.408479e+09
# 44286        World          WLD  ...  6.575068e+01  6.606914e+01
# 44287        World          WLD  ...  1.034448e+00  1.012493e+00
#
# [173 rows x 95 columns]

# %%
world_total_population = df.loc[(df['Country Name'] == 'World') & (df['Series Name'] == 'Population, total' )]
world_total_population
# Out:
#       Country Name Country Code  ... 2049 [YR2049] 2050 [YR2050]
# 44280        World          WLD  ...  9.671774e+09  9.722319e+09
#
# [1 rows x 95 columns]

# %%
col_name = df.columns[4:]
years = []
for col in df.columns[4:]:
  years.append(col[:4])
print(col_name)
print(years)
# Out:
# Index(['1960 [YR1960]', '1961 [YR1961]', '1962 [YR1962]', '1963 [YR1963]',
#        '1964 [YR1964]', '1965 [YR1965]', '1966 [YR1966]', '1967 [YR1967]',
#        '1968 [YR1968]', '1969 [YR1969]', '1970 [YR1970]', '1971 [YR1971]',
#        '1972 [YR1972]', '1973 [YR1973]', '1974 [YR1974]', '1975 [YR1975]',
#        '1976 [YR1976]', '1977 [YR1977]', '1978 [YR1978]', '1979 [YR1979]',
#        '1980 [YR1980]', '1981 [YR1981]', '1982 [YR1982]', '1983 [YR1983]',
#        '1984 [YR1984]', '1985 [YR1985]', '1986 [YR1986]', '1987 [YR1987]',
#        '1988 [YR1988]', '1989 [YR1989]', '1990 [YR1990]', '1991 [YR1991]',
#        '1992 [YR1992]', '1993 [YR1993]', '1994 [YR1994]', '1995 [YR1995]',
#        '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]', '1999 [YR1999]',
#        '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]',
#        '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]',
#        '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]',
#        '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]',
#        '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]',
#        '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]', '2023 [YR2023]',
#        '2024 [YR2024]', '2025 [YR2025]', '2026 [YR2026]', '2027 [YR2027]',
#        '2028 [YR2028]', '2029 [YR2029]', '2030 [YR2030]', '2031 [YR2031]',
#        '2032 [YR2032]', '2033 [YR2033]', '2034 [YR2034]', '2035 [YR2035]',
#        '2036 [YR2036]', '2037 [YR2037]', '2038 [YR2038]', '2039 [YR2039]',
#        '2040 [YR2040]', '2041 [YR2041]', '2042 [YR2042]', '2043 [YR2043]',
#        '2044 [YR2044]', '2045 [YR2045]', '2046 [YR2046]', '2047 [YR2047]',
#        '2048 [YR2048]', '2049 [YR2049]', '2050 [YR2050]'],
#       dtype='object')
# ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025', '2026', '2027', '2028', '2029', '2030', '2031', '2032', '2033', '2034', '2035', '2036', '2037', '2038', '2039', '2040', '2041', '2042', '2043', '2044', '2045', '2046', '2047', '2048', '2049', '2050']

# %%
world_total_population.values.reshape(95,1)
world_total_population1 = world_total_population.iloc[: , 4:]

# %% [markdown]
# # Annual world population growth rate.

# %% [markdown]
# 1. When null values are changed with median

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(64, 16))
plt.plot(years, world_total_population[col_name].values.reshape(91,1))
plt.title('Annual world population growth rate',size = 40)
plt.xlabel('Year',size = 40)
plt.ylabel('Population',size = 40)
plt.show()

# %% [markdown]
# 2. When null values are changed with mean

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(64, 16))
plt.plot(years,  df2[col_name].sum())
plt.title('Annual world population growth rate',size = 40)
plt.xlabel('Year',size = 40)
plt.ylabel('Population',size = 40)
plt.show()

# %% [markdown]
# 3. When null values are changed with zero

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(64, 16))
plt.plot(years,  df3[col_name].sum())
plt.title('Annual world population growth rate',size = 40)
plt.xlabel('Year',size = 40)
plt.ylabel('Population',size = 40)
plt.show()

# %%
regions = df['Country Name'].unique()
print(regions)
print("No. of regions =",len(regions))
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Arab World' 'Argentina' 'Armenia' 'Aruba'
#  'Australia' 'Austria' 'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh'
#  'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan'
#  'Bolivia' 'Bosnia and Herzegovina' 'Botswana' 'Brazil'
#  'British Virgin Islands' 'Brunei Darussalam' 'Bulgaria' 'Burkina Faso'
#  'Burundi' 'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada'
#  'Caribbean small states' 'Cayman Islands' 'Central African Republic'
#  'Central Europe and the Baltics' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czech Republic'
#  'Denmark' 'Djibouti' 'Dominica' 'Dominican Republic'
#  'Early-demographic dividend' 'East Asia & Pacific'
#  'East Asia & Pacific (excluding high income)'
#  'East Asia & Pacific (IDA & IBRD countries)' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Ethiopia'
#  'Euro area' 'Europe & Central Asia'
#  'Europe & Central Asia (excluding high income)'
#  'Europe & Central Asia (IDA & IBRD countries)' 'European Union'
#  'Faroe Islands' 'Fiji' 'Finland'
#  'Fragile and conflict affected situations' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
#  'Greenland' 'Grenada' 'Guam' 'Guatemala' 'Guinea' 'Guinea-Bissau'
#  'Guyana' 'Haiti' 'Heavily indebted poor countries (HIPC)' 'High income'
#  'Honduras' 'Hong Kong SAR, China' 'Hungary' 'Iceland' 'India' 'Indonesia'
#  'Iran, Islamic Rep.' 'Iraq' 'Ireland' 'Isle of Man' 'Israel' 'Italy'
#  'Jamaica' 'Japan' 'Jordan' 'Kazakhstan' 'Kenya' 'Kiribati'
#  'Korea, Dem. People’s Rep.' 'Korea, Rep.' 'Kosovo' 'Kuwait'
#  'Kyrgyz Republic' 'Lao PDR' 'Late-demographic dividend'
#  'Latin America & Caribbean'
#  'Latin America & Caribbean (excluding high income)'
#  'Latin America & the Caribbean (IDA & IBRD countries)' 'Latvia'
#  'Least developed countries: UN classification' 'Lebanon' 'Lesotho'
#  'Liberia' 'Libya' 'Liechtenstein' 'Lithuania' 'Low & middle income'
#  'Low income' 'Lower middle income' 'Luxembourg' 'Macao SAR, China'
#  'Macedonia, FYR' 'Madagascar' 'Malawi' 'Malaysia' 'Maldives' 'Mali'
#  'Malta' 'Marshall Islands' 'Mauritania' 'Mauritius' 'Mexico'
#  'Micronesia, Fed. Sts.' 'Middle East & North Africa'
#  'Middle East & North Africa (excluding high income)'
#  'Middle East & North Africa (IDA & IBRD countries)' 'Middle income'
#  'Moldova' 'Monaco' 'Mongolia' 'Montenegro' 'Morocco' 'Mozambique'
#  'Myanmar' 'Namibia' 'Nauru' 'Nepal' 'Netherlands' 'New Caledonia'
#  'New Zealand' 'Nicaragua' 'Niger' 'Nigeria' 'North America'
#  'Northern Mariana Islands' 'Norway' 'Not classified' 'OECD members'
#  'Oman' 'Other small states' 'Pacific island small states' 'Pakistan'
#  'Palau' 'Panama' 'Papua New Guinea' 'Paraguay' 'Peru' 'Philippines'
#  'Poland' 'Portugal' 'Post-demographic dividend'
#  'Pre-demographic dividend' 'Puerto Rico' 'Qatar' 'Romania'
#  'Russian Federation' 'Rwanda' 'Samoa' 'San Marino'
#  'Sao Tome and Principe' 'Saudi Arabia' 'Senegal' 'Serbia' 'Seychelles'
#  'Sierra Leone' 'Singapore' 'Sint Maarten (Dutch part)' 'Slovak Republic'
#  'Slovenia' 'Small states' 'Solomon Islands' 'Somalia' 'South Africa'
#  'South Asia' 'South Asia (IDA & IBRD)' 'South Sudan' 'Spain' 'Sri Lanka'
#  'St. Kitts and Nevis' 'St. Lucia' 'St. Martin (French part)'
#  'St. Vincent and the Grenadines' 'Sub-Saharan Africa'
#  'Sub-Saharan Africa (excluding high income)'
#  'Sub-Saharan Africa (IDA & IBRD countries)' 'Sudan' 'Suriname'
#  'Swaziland' 'Sweden' 'Switzerland' 'Syrian Arab Republic' 'Tajikistan'
#  'Tanzania' 'Thailand' 'Timor-Leste' 'Togo' 'Tonga' 'Trinidad and Tobago'
#  'Tunisia' 'Turkey' 'Turkmenistan' 'Turks and Caicos Islands' 'Tuvalu'
#  'Uganda' 'Ukraine' 'United Arab Emirates' 'United Kingdom'
#  'United States' 'Upper middle income' 'Uruguay' 'Uzbekistan' 'Vanuatu'
#  'Venezuela, RB' 'Vietnam' 'Virgin Islands (U.S.)' 'West Bank and Gaza'
#  'World' 'Yemen, Rep.' 'Zambia' 'Zimbabwe']
# No. of regions = 259

# %% [markdown]
# # World population by region

# %%
plt.figure(figsize=(64, 80))
for reg in regions:
  plt.plot(years, df[df['Country Name']==reg].sum()[4:], label= reg)
plt.title('World population by region')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.show()

# %% [markdown]
# 10 Countries plot

# %%
countries = ['World', 'India', 'China', 'United States', 'Nigeria', 'Bangladesh', 'Indonesia', 'Brazil', 'Russian Federation', 'Mexico']

# %%
top_ten = df.loc[(df['Country Name'].isin(countries[1:])) & (df['Series Name'] == 'Population, total')].set_index('Country Name')[numeric_cols]
top_ten
# Out:
#                     1960 [YR1960]  1961 [YR1961]  ...  2049 [YR2049]  2050 [YR2050]
# Country Name                                      ...
# Bangladesh             48199747.0     49592802.0  ...   2.015890e+08   2.019270e+08
# Brazil                 72207554.0     74351763.0  ...   2.327850e+08   2.326880e+08
# China                 667070000.0    660330000.0  ...   1.345054e+09   1.338382e+09
# India                 449480608.0    458494963.0  ...   1.655153e+09   1.658978e+09
# Indonesia              87792515.0     90138235.0  ...   3.209210e+08   3.215510e+08
# Mexico                 38174112.0     39394126.0  ...   1.637830e+08   1.642790e+08
# Nigeria                45137812.0     46062905.0  ...   4.026280e+08   4.106380e+08
# Russian Federation    119897000.0    121236000.0  ...   1.297030e+08   1.293580e+08
# United States         180671000.0    183691000.0  ...   3.839100e+08   3.853570e+08
#
# [9 rows x 91 columns]

# %%
import plotly.express as px

fig = px.line(top_ten.T, title='Total population of some countries')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c68505c9-0ef2-4dde-a1d9-c471d0bc904d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c68505c9-0ef2-4dde-a1d9-c471d0bc904d")) {                    Plotly.newPlot(                        "c68505c9-0ef2-4dde-a1d9-c471d0bc904d",                        [{"hovertemplate":"Country Name=Bangladesh<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Bangladesh","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bangladesh","orientation":"v","showlegend":true,"x":["1960 [YR1960]","1961 [YR1961]","1962 [YR1962]","1963 [YR1963]","1964 [YR1964]","1965 [YR1965]","1966 [YR1966]","1967 [YR1967]","1968 [YR1968]","1969 [YR1969]","1970 [YR1970]","1971 [YR1971]","1972 [YR1972]","1973 [YR1973]","1974 [YR1974]","1975 [YR1975]","1976 [YR1976]","1977 [YR1977]","1978 [YR1978]","1979 [YR1979]","1980 [YR1980]","1981 [YR1981]","1982 [YR1982]","1983 [YR1983]","1984 [YR1984]","1985 [YR1985]","1986 [YR1986]","1987 [YR1987]","1988 [YR1988]","1989 [YR1989]","1990 [YR1990]","1991 [YR1991]","1992 [YR1992]","1993 [YR1993]","1994 [YR1994]","1995 [YR1995]","1996 [YR1996]","1997 [YR1997]","1998 [YR1998]","1999 [YR1999]","2000 [YR2000]","2001 [YR2001]","2002 [YR2002]","2003 [YR2003]","2004 [YR2004]","2005 [YR2005]","2006 [YR2006]","2007 [YR2007]","2008 [YR2008]","2009 [YR2009]","2010 [YR2010]","2011 [YR2011]","2012 [YR2012]","2013 [YR2013]","2014 [YR2014]","2015 [YR2015]","2016 [YR2016]","2017 [YR2017]","2018 [YR2018]","2019 [YR2019]","2020 [YR2020]","2021 [YR2021]","2022 [YR2022]","2023 [YR2023]","2024 [YR2024]","2025 [YR2025]","2026 [YR2026]","2027 [YR2027]","2028 [YR2028]","2029 [YR2029]","2030 [YR2030]","2031 [YR2031]","2032 [YR2032]","2033 [YR2033]","2034 [YR2034]","2035 [YR2035]","2036 [YR2036]","2037 [YR2037]","2038 [YR2038]","2039 [YR2039]","2040 [YR2040]","2041 [YR2041]","2042 [YR2042]","2043 [YR2043]","2044 [YR2044]","2045 [YR2045]","2046 [YR2046]","2047 [YR2047]","2048 [YR2048]","2049 [YR2049]","2050 [YR2050]"],"xaxis":"x","y":[48199747.0,49592802.0,51030137.0,52532417.0,54129100.0,55834038.0,57672990.0,59620669.0,61579473.0,63417394.0,65047770.0,66424744.0,67597470.0,68691185.0,69884420.0,71305923.0,72999136.0,74925896.0,77033846.0,79236776.0,81470860.0,83721268.0,86007331.0,88338242.0,90732362.0,93199865.0,95742431.0,98343809.0,100975321.0,103599232.0,106188642.0,108727432.0,111221938.0,113695139.0,116182267.0,118706871.0,121269645.0,123854640.0,126447965.0,129029691.0,131581243.0,134107160.0,136600667.0,139019001.0,141307489.0,143431101.0,145368004.0,147139191.0,148805814.0,150454708.0,152149102.0,153911916.0,155727053.0,157571292.0,159405279.0,161200886.0,162951560.0,164670000.0,166368000.0,168066000.0,169775000.0,171500000.0,173229000.0,174947000.0,176631000.0,178263000.0,179836000.0,181353000.0,182815000.0,184224000.0,185585000.0,186895000.0,188151000.0,189354000.0,190504000.0,191601000.0,192643000.0,193633000.0,194570000.0,195457000.0,196294000.0,197083000.0,197824000.0,198515000.0,199155000.0,199744000.0,200281000.0,200767000.0,201203000.0,201589000.0,201927000.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Brazil<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Brazil","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Brazil","orientation":"v","showlegend":true,"x":["1960 [YR1960]","1961 [YR1961]","1962 [YR1962]","1963 [YR1963]","1964 [YR1964]","1965 [YR1965]","1966 [YR1966]","1967 [YR1967]","1968 [YR1968]","1969 [YR1969]","1970 [YR1970]","1971 [YR1971]","1972 [YR1972]","1973 [YR1973]","1974 [YR1974]","1975 [YR1975]","1976 [YR1976]","1977 [YR1977]","1978 [YR1978]","1979 [YR1979]","1980 [YR1980]","1981 [YR1981]","1982 [YR1982]","1983 [Y ...

# %% [markdown]
# # Growth of the population by age group

# %%
df3=pd.DataFrame(df.iloc[:,:4])
df3.rename(columns={'Country Name':'CName','Country Code':'CCode','Series Name':'SName','Series Code':'SCode'},inplace=True)
df4=pd.DataFrame(df.iloc[:,4:])
years=list(map(int,range(1960,2051)))
df4.columns=years
df_new = df3.join(df4, how='outer')
df_new
# Out:
#              CName CCode  ...          2049          2050
# 0      Afghanistan   AFG  ...  4.447150e+01  4.399248e+01
# 1      Afghanistan   AFG  ...  7.935899e+00  8.175734e+00
# 2      Afghanistan   AFG  ...  3.653560e+01  3.581675e+01
# 3      Afghanistan   AFG  ...  6.723943e+01  4.300000e+05
# 4      Afghanistan   AFG  ...  6.723943e+01  4.520000e+05
# ...            ...   ...  ...           ...           ...
# 44802     Zimbabwe   ZWE  ...  6.723943e+01  2.100000e+04
# 44803     Zimbabwe   ZWE  ...  6.723943e+01  2.100000e+04
# 44804     Zimbabwe   ZWE  ...  1.263300e+07  1.296800e+07
# 44805     Zimbabwe   ZWE  ...  4.315700e+01  4.372400e+01
# 44806     Zimbabwe   ZWE  ...  6.723943e+01  2.100000e+04
#
# [44807 rows x 95 columns]

# %%
df_SName=pd.DataFrame(df_new.iloc[:,2:])
df_SName.drop(['SCode'],axis=1,inplace=True)
df_SName_grouped=df_SName.groupby(['SName']).mean()
df_SName_grouped.reset_index(inplace=True)
df_SName_grouped.columns = list(map(str, df_SName_grouped.columns))
df_SName_grouped
# Out:
#                                                  SName  ...          2050
# 0    Age dependency ratio (% of working-age populat...  ...  2.163594e+03
# 1                            Age dependency ratio, old  ...  2.133056e+03
# 2                          Age dependency ratio, young  ...  2.138588e+03
# 3          Age population, age 0, female, interpolated  ...  2.680320e+05
# 4            Age population, age 0, male, interpolated  ...  2.818853e+05
# ..                                                 ...  ...           ...
# 168                 Rural population growth (annual %)  ...  1.767559e+04
# 169  Sex ratio at birth (male births per female bir...  ...  2.100000e+04
# 170                                   Urban population  ...  2.174234e+08
# 171                      Urban population (% of total)  ...  3.927727e+02
# 172                 Urban population growth (annual %)  ...  1.767585e+04
#
# [173 rows x 92 columns]

# %%
list_SName=df_SName_grouped['SName'].tolist()
list_SName
# Out:
# ['Age dependency ratio (% of working-age population)',
#  'Age dependency ratio, old',
#  'Age dependency ratio, young',
#  'Age population, age 0, female, interpolated',
#  'Age population, age 0, male, interpolated',
#  'Age population, age 01, female, interpolated',
#  'Age population, age 01, male, interpolated',
#  'Age population, age 02, female, interpolated',
#  'Age population, age 02, male, interpolated',
#  'Age population, age 03, female, interpolated',
#  'Age population, age 03, male, interpolated',
#  'Age population, age 04, female, interpolated',
#  'Age population, age 04, male, interpolated',
#  'Age population, age 05, female, interpolated',
#  'Age population, age 05, male, interpolated',
#  'Age population, age 06, female, interpolated',
#  'Age population, age 06, male, interpolated',
#  'Age population, age 07, female, interpolated',
#  'Age population, age 07, male, interpolated',
#  'Age population, age 08, female, interpolated',
#  'Age population, age 08, male, interpolated',
#  'Age population, age 09, female, interpolated',
#  'Age population, age 09, male, interpolated',
#  'Age population, age 10, female, interpolated',
#  'Age population, age 10, male, interpolated',
#  'Age population, age 11, female, interpolated',
#  'Age population, age 11, male, interpolated',
#  'Age population, age 12, female, interpolated',
#  'Age population, age 12, male, interpolated',
#  'Age population, age 13, female, interpolated',
#  'Age population, age 13, male, interpolated',
#  'Age population, age 14, female, interpolated',
#  'Age population, age 14, male, interpolated',
#  'Age population, age 15, female, interpolated',
#  'Age population, age 15, male, interpolated',
#  'Age population, age 16, female, interpolated',
#  'Age population, age 16, male, interpolated',
#  'Age population, age 17, female, interpolated',
#  'Age population, age 17, male, interpolated',
#  'Age population, age 18, female, interpolated',
#  'Age population, age 18, male, interpolated',
#  'Age population, age 19, female, interpolated',
#  'Age population, age 19, male, interpolated',
#  'Age population, age 20, female, interpolated',
#  'Age population, age 20, male, interpolated',
#  'Age population, age 21, female, interpolated',
#  'Age population, age 21, male, interpolated',
#  'Age population, age 22, female, interpolated',
#  'Age population, age 22, male, interpolated',
#  'Age population, age 23, female, interpolated',
#  'Age population, age 23, male, interpolated',
#  'Age population, age 24, female, interpolated',
#  'Age population, age 24, male, interpolated',
#  'Age population, age 25, female, interpolated',
#  'Age population, age 25, male, interpolated',
#  'Birth rate, crude (per 1,000 people)',
#  'Death rate, crude (per 1,000 people)',
#  'Female population 00-04',
#  'Female population 05-09',
#  'Female population 10-14',
#  'Female population 15-19',
#  'Female population 20-24',
#  'Female population 25-29',
#  'Female population 30-34',
#  'Female population 35-39',
#  'Female population 40-44',
#  'Female population 45-49',
#  'Female population 50-54',
#  'Female population 55-59',
#  'Female population 60-64',
#  'Female population 65-69',
#  'Female population 70-74',
#  'Female population 75-79',
#  'Female population 80+',
#  'Fertility rate, total (births per woman)',
#  'Life expectancy at birth, female (years)',
#  'Life expectancy at birth, male (years)',
#  'Life expectancy at birth, total (years)',
#  'Male population 00-04',
#  'Male population 05-09',
#  'Male population 10-14',
#  'Male population 15-19',
#  'Male population 20-24',
#  'Male population 25-29',
#  'Male population 30-34',
#  'Male population 35-39',
#  'Male population 40-44',
#  'Male population 45-49',
#  'Male population 50-54',
#  'Male population 55-59',
#  'Male population 60-64',
#  'Male population 65-69',
#  'Male population 70-74',
#  'Male population 75-79',
#  'Male population 80+',
#  'Mortality rate, adult, female (per 1,000 female adults)',
#  'Mortality rate, adult, male (per 1,000 male adults)',
#  'Mortality rate, infant (per 1,000 live births)',
#  'Mortality rate, infant, female (per 1,000 live births)',
#  'Mortality rate, infant, male (per 1,000 live births)',
#  'Mortality rate, neonatal (per 1,000 live births)',
#  'Mortality rate, under-5 (per 1,000)',
#  'Mortality rate, under-5, female (per 1,000)',
#  'Mortality rate, under-5, male (per 1,000)',
#  'Net migration',
#  'Number of infant deaths',
#  'Number of neonatal deaths',
#  'Number of under-five deaths',
#  'Population ages 0-14, female',
#  'Population ages 0-14, male',
#  'Population ages 00-04, female (% of female population)',
#  'Population ages 00-04, male (% of male population)',
#  'Population ages 00-14 (% of total)',
#  'Population ages 00-14, female (% of total)',
#  'Population ages 00-14, male (% of total)',
#  'Population ages 00-14, total',
#  'Population ages 05-09, female (% of female population)',
#  'Population ages 05-09, male (% of male population)',
#  'Population ages 10-14, female (% of female population)',
#  'Population ages 15-19, female (% of female population)',
#  'Population ages 15-19, male (% of male population)',
#  'Population ages 15-64 (% of total)',
#  'Population ages 15-64, female',
#  'Population ages 15-64, female (% of total)',
#  'Population ages 15-64, male',
#  'Population ages 15-64, male (% of total)',
#  'Population ages 15-64, total',
#  'Population ages 20-24, female (% of female population)',
#  'Population ages 20-24, male (% of male population)',
#  'Population ages 25-29, female (% of female population)',
#  'Population ages 25-29, male (% of male population)',
#  'Population ages 30-34, female (% of female population)',
#  'Population ages 30-34, male (% of male population)',
#  'Population ages 35-39, female (% of female population)',
#  'Population ages 35-39, male (% of male population)',
#  'Population ages 40-44, female (% of female population)',
#  'Population ages 40-44, male (% of male population)',
#  'Population ages 45-49, female (% of female population)',
#  'Population ages 45-49, male (% of male population)',
#  'Population ages 50-54, female (% of female population)',
#  'Population ages 50-54, male (% of male population)',
#  'Population ages 55-59, female (% of female population)',
#  'Population ages 55-59, male (% of male population)',
#  'Population ages 60-64, female (% of female population)',
#  'Population ages 60-64, male (% of male population)',
#  'Population ages 65 and above (% of total)',
#  'Population ages 65 and above, female',
#  'Population ages 65 and above, female (% of total)',
#  'Population ages 65 and above, male',
#  'Population ages 65 and above, male (% of total)',
#  'Population ages 65 and above, total',
#  'Population ages 65-69, female (% of female population)',
#  'Population ages 65-69, male (% of male population)',
#  'Population ages 70-74, female (% of female population)',
#  'Population ages 70-74, male (% of male population)',
#  'Population ages 75-79, female (% of female population)',
#  'Population ages 75-79, male (% of male population)',
#  'Population ages 80 and older, female (% of female population)',
#  'Population ages 80 and older, male (% of male population)',
#  'Population ages10-14, male (% of male population)',
#  'Population growth (annual %)',
#  'Population, female',
#  'Population, female (% of total)',
#  'Population, male',
#  'Population, male (% of total)',
#  'Population, total',
#  'Rural population',
#  'Rural population (% of total population)',
#  'Rural population growth (annual %)',
#  'Sex ratio at birth (male births per female births)',
#  'Urban population',
#  'Urban population (% of total)',
#  'Urban population growth (annual %)']

# %%
#world annual female population by ages
list_SName.index('Female population 00-04')
list_SName.index('Female population 80+')
df_female=df_SName_grouped.loc[57:73,:].transpose()
df_female=df_female.rename(columns=df_female.iloc[0]).iloc[1:]
df_female['years']=df_female.index
df_female= df_female.reset_index(drop=True)
#matplotlib.pyplot.colors()
ax1=df_female.plot(x='years',y='Female population 00-04',figsize=(25,10),label='Female population 00-04',color='r')
df_female.plot(x='years',y='Female population 05-09',figsize=(25,10),label='Female population 05-09',color='b',ax=ax1)
df_female.plot(x='years',y='Female population 10-14',figsize=(25,10),label='Female population 10-14',color='g',ax=ax1)
df_female.plot(x='years',y='Female population 15-19',figsize=(25,10),label='Female population 15-19',color='c',ax=ax1)
df_female.plot(x='years',y='Female population 20-24',figsize=(25,10),label='Female population 20-24',color='m',ax=ax1)
df_female.plot(x='years',y='Female population 25-29',figsize=(25,10),label='Female population 25-29',color='y',ax=ax1)
df_female.plot(x='years',y='Female population 30-34',figsize=(25,10),label='Female population 30-34',color='k',ax=ax1)
df_female.plot(x='years',y='Female population 35-39',figsize=(25,10),label='Female population 35-39',color='#008000',ax=ax1)
df_female.plot(x='years',y='Female population 40-44',figsize=(25,10),label='Female population 40-44',color='#00FFFF',ax=ax1)
df_female.plot(x='years',y='Female population 45-49',figsize=(25,10),label='Female population 45-49',color='#ED0DD9',ax=ax1)
df_female.plot(x='years',y='Female population 50-54',figsize=(25,10),label='Female population 50-54',color='#C20078',ax=ax1)
df_female.plot(x='years',y='Female population 55-59',figsize=(25,10),label='Female population 55-59',color='#FFA500',ax=ax1)
df_female.plot(x='years',y='Female population 60-64',figsize=(25,10),label='Female population 60-64',color='#380282',ax=ax1)
df_female.plot(x='years',y='Female population 65-69',figsize=(25,10),label='Female population 65-69',color='#C5C9C7',ax=ax1)
df_female.plot(x='years',y='Female population 70-74',figsize=(25,10),label='Female population 70-74',color='#808080',ax=ax1)
df_female.plot(x='years',y='Female population 75-79',figsize=(25,10),label='Female population 75-79',color='#13EAC9',ax=ax1)
df_female.plot(x='years',y='Female population 80+',figsize=(25,15),label='Female population 80+',color='#CBB40C',ax=ax1)
ax = plt.gca()
#ax.set_xticklabels(labels=years,rotation=90)
plt.legend(loc='upper left');
plt.show()

# %%
#world annual male population by ages
list_SName.index('Male population 00-04')
list_SName.index('Male population 80+')
df_male=df_SName_grouped.loc[78:94,:].transpose()
df_male=df_male.rename(columns=df_male.iloc[0]).iloc[1:]
df_male['years']=df_male.index
df_male= df_male.reset_index(drop=True)
#matplotlib.pyplot.colors()
ax1=df_male.plot(x='years',y='Male population 00-04',figsize=(25,10),label='male population 00-04',color='r')
df_male.plot(x='years',y='Male population 05-09',figsize=(25,10),label='male population 05-09',color='b',ax=ax1)
df_male.plot(x='years',y='Male population 10-14',figsize=(25,10),label='male population 10-14',color='g',ax=ax1)
df_male.plot(x='years',y='Male population 15-19',figsize=(25,10),label='male population 15-19',color='c',ax=ax1)
df_male.plot(x='years',y='Male population 20-24',figsize=(25,10),label='male population 20-24',color='m',ax=ax1)
df_male.plot(x='years',y='Male population 25-29',figsize=(25,10),label='male population 25-29',color='y',ax=ax1)
df_male.plot(x='years',y='Male population 30-34',figsize=(25,10),label='male population 30-34',color='k',ax=ax1)
df_male.plot(x='years',y='Male population 35-39',figsize=(25,10),label='male population 35-39',color='#000000',ax=ax1)
df_male.plot(x='years',y='Male population 40-44',figsize=(25,10),label='male population 40-44',color='#00FFFF',ax=ax1)
df_male.plot(x='years',y='Male population 45-49',figsize=(25,10),label='male population 45-49',color='#ED0DD9',ax=ax1)
df_male.plot(x='years',y='Male population 50-54',figsize=(25,10),label='male population 50-54',color='#FE420F',ax=ax1)
df_male.plot(x='years',y='Male population 55-59',figsize=(25,10),label='male population 55-59',color='#FFA500',ax=ax1)
df_male.plot(x='years',y='Male population 60-64',figsize=(25,10),label='male population 60-64',color='#380282',ax=ax1)
df_male.plot(x='years',y='Male population 65-69',figsize=(25,10),label='male population 65-69',color='#C5C9C7',ax=ax1)
df_male.plot(x='years',y='Male population 70-74',figsize=(25,10),label='male population 70-74',color='#808080',ax=ax1)
df_male.plot(x='years',y='Male population 75-79',figsize=(25,10),label='male population 75-79',color='#13EAC9',ax=ax1)
df_male.plot(x='years',y='Male population 80+',figsize=(25,15),label='male population 80+',color='#CBB40C',ax=ax1)
# ax = plt.gca()
# ax.set_xticklabels(labels=years,rotation=90)
plt.legend(loc='upper left');
plt.show()

# %% [markdown]
# # Train-Test Split

# %%
# spliting training and testing data
from sklearn.model_selection import train_test_split

X = df.iloc[:,4:-1]
y = df['2050 [YR2050]']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=27)

# %%
X_train
# Out:
#        1960 [YR1960]  1961 [YR1961]  ...  2048 [YR2048]  2049 [YR2049]
# 7118    32045.000000   34285.000000  ...      67.365858      67.239426
# 42422  353861.000000  367524.000000  ...      67.365858      67.239426
# 34555       8.497487       8.506167  ...       5.997944       5.940739
# 11404      12.020133      12.111055  ...       8.687278       8.691780
# 5965   209546.000000  213651.000000  ...  820000.000000  811000.000000
# ...              ...            ...  ...            ...            ...
# 29989    4704.500000    4657.500000  ...      67.365858      67.239426
# 4848     4704.500000    4657.500000  ...      67.365858      67.239426
# 14879       4.488151       4.530450  ...       9.393410       9.575853
# 36680    4704.500000    4657.500000  ...      67.365858      67.239426
# 5139    20574.000000   21285.000000  ...  161000.000000  160000.000000
#
# [35845 rows x 90 columns]

# %%
y_train
# Out:
# 7118     400000.000000
# 42422    395000.000000
# 34555         5.880700
# 11404         8.678837
# 5965     803000.000000
#              ...
# 29989     21000.000000
# 4848      21000.000000
# 14879         9.752565
# 36680     21000.000000
# 5139     159000.000000
# Name: 2050 [YR2050], Length: 35845, dtype: float64

# %%
# data standardization with  sklearn
from sklearn.preprocessing import StandardScaler

# copy of datasets
X_train_stand = X_train.copy()
X_test_stand = X_test.copy()


# apply standardization on numerical features
for i in col_name[:-1]:
    
    # fit on training data column
    scale = StandardScaler().fit(X_train_stand[[i]])
    
    # transform the training data column
    X_train_stand[i] = scale.transform(X_train_stand[[i]])
    
    # transform the testing data column
    X_test_stand[i] = scale.transform(X_test_stand[[i]])

# %% [markdown]
# # Multiple Linear Regression

# %%
#Fitting Linear Regression to the training set
from sklearn.linear_model import LinearRegression
multiple_reg = LinearRegression()
multiple_reg.fit(X_train_stand, y_train)
# Out:
# LinearRegression()

# %%
#predicting the Test set result
y_pred = multiple_reg.predict(X_test_stand)

# %%
y_pred
# Out:
# array([1.90523484e+04, 2.31746624e+05, 2.12373695e+04, ...,
#        9.28039673e+03, 6.13202197e+01, 4.01636384e+05])

# %%
multiple_reg.coef_
# Out:
# array([-9.87937718e+04, -1.13038776e+06,  1.02529161e+06,  2.33919776e+05,
#         2.74588948e+06, -4.06056076e+06,  2.18509747e+06, -4.54645348e+05,
#        -4.49210438e+05,  1.84462841e+05, -4.99916591e+06,  5.30628369e+06,
#         3.30424452e+04,  3.11791272e+06, -4.76152995e+06,  1.27549636e+06,
#        -1.45680879e+06,  5.14439216e+04,  1.16696749e+07, -2.28038393e+07,
#         1.41366149e+07, -9.50509050e+05,  3.53671755e+05,  4.42216541e+06,
#        -1.32458954e+07,  8.31111291e+06,  1.23763070e+05, -1.10840127e+06,
#         5.85005257e+05, -2.14875490e+05,  2.49171098e+06, -4.00468362e+06,
#         3.25734601e+05,  3.15232344e+06, -5.28900623e+06,  4.38332269e+06,
#         2.72006802e+05,  1.08649201e+06, -5.60275683e+06,  3.78551566e+06,
#        -1.36597492e+06, -7.16788191e+05, -2.81331651e+03,  5.32301051e+06,
#        -5.42149245e+06,  5.51307434e+06, -5.66891891e+06, -3.14043516e+05,
#         6.67337441e+06, -9.83598844e+06,  6.44220912e+06, -1.05811390e+06,
#         9.30619872e+05, -8.85586176e+06,  1.41640410e+07, -6.43327798e+06,
#         9.24781003e+06, -8.72589650e+06, -2.75036354e+07,  4.93875008e+07,
#        -2.57078321e+07,  3.48494412e+06, -2.91350626e+06,  9.04606156e+06,
#        -1.05796070e+07,  4.91001471e+06, -8.00036058e+06,  1.58458950e+07,
#         1.32884019e+07, -3.82591337e+07,  2.78988775e+06,  3.34072018e+06,
#        -3.70379440e+07,  1.17848775e+08, -7.39564160e+07,  6.13912934e+07,
#        -1.30461495e+08,  7.31883636e+06,  1.11003369e+08,  7.83713530e+07,
#        -1.93721554e+08,  4.73618174e+07, -6.20828761e+07,  2.81286672e+08,
#        -4.14399257e+08,  2.85191010e+08, -1.03813200e+07,  9.08038763e+07,
#        -4.63652981e+08,  4.59875554e+08])

# %%
#Calculating the R squared value
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9999999976912131

# %% [markdown]
# # Clustering

# %%
#Modelling
# Creating a variable X1 and assigning the values to it.
X1 = data_numeric.values
X1[np.isinf(X1)] = np.max(X1)
X1[np.isnan(X1)] = np.mean(X1)

# %%
from sklearn.cluster import KMeans   #Importing KMeans from sklearn and
k_inertia = []                       # Creating a list to store the kmeans.inertia_
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(X1)
    k_inertia.append(kmeans.inertia_)
